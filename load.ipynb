# %%
import torch
from torch import nn
from vis import LSTMModel

# %%
CHECKPOINT_PATH = 'stock_predictor_model.pth'
checkpoint = torch.load(CHECKPOINT_PATH, weights_only=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Out:
# [{'type': 'LSTM', 'input_size': 5, 'hidden_size': 1028, 'num_layers': 4, 'output_size': 1028}, {'type': 'linear', 'input_size': 1028, 'hidden_size': 128, 'output_size': 128}, {'type': 'linear', 'input_size': 128, 'hidden_size': 64, 'output_size': 64}, {'type': 'linear', 'input_size': 64, 'hidden_size': 1, 'output_size': 1}]
